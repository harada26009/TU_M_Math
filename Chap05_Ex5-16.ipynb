# %% [markdown]
# <a href="https://colab.research.google.com/github/harada26009/TU_M_Math/blob/main/Chap05_Ex5-16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from ast import increment_lineno
import numpy as np
import numpy.random as random
import scipy as sp

import matplotlib.pyplot as plot
import matplotlib as mpl
# %matplotlib inline

# %precision 3
# Out:
# '%.3f'

# %%
import math
from numpy import cos

integrate.quad(cos,0,math.pi/1)
# Out:
# (0.000, 0.000)
