# %% [markdown]
# <a href="https://colab.research.google.com/github/harada26009/TU_M_Math/blob/main/Chap05_Ex5-12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from ast import increment_lineno
import numpy as np
import numpy.random as random
import scipy as sp

import matplotlib.pyplot as plot
import matplotlib as mpl
# %matplotlib inline

# %precision 3
# Out:
# '%.3f'

# %%
x = np.linspace(0,10,num=11,endpoint=True)
y = np.sin(x**2/5.0)
plot.plot(x,y,'o')
plot.grid(True)

# %%
from scipy import interpolate

f = interpolate.interp1d(x,y,'linear')
plot.plot(x,f(x),'-')
plot.grid(True)

# %%
f2 = interpolate.interp1d(x,y,'quadratic')
xnew = np.linspace(0,10,num=30,endpoint=True)
plot.plot(x,y,'o',xnew,f(xnew),'-',xnew,f2(xnew),'--')
plot.legend(['data','linear','quadratic'],loc='best')
plot.grid(True)

# %%
f2 = interpolate.interp1d(x,y,'quadratic')
f3 = interpolate.interp1d(x,y,'cubic')

xnew = np.linspace(0,10,num=30,endpoint=True)
plot.plot(x,y,'o',xnew,f(xnew),'-',xnew,f2(xnew),'--',xnew,f3(xnew),'--')

plot.legend(['data','linear','quadratic','cubic'],loc='best')
plot.grid(True)
