# %% [markdown]
# <a href="https://colab.research.google.com/github/harada26009/TU_M_Math/blob/main/PyCaret_ex_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#install pycaret library
# !pip install pycaret

#confirm if pycaret was installed
from pycaret.utils import version
version()
# Out:
# ...
# '3.3.2'

# %%
from pycaret.datasets import get_data
data = get_data('juice')
# Out:
#    Id Purchase  WeekofPurchase  StoreID  PriceCH  PriceMM  DiscCH  DiscMM  \
# 0   1       CH             237        1     1.75     1.99    0.00     0.0
# 1   2       CH             239        1     1.75     1.99    0.00     0.3
# 2   3       CH             245        1     1.86     2.09    0.17     0.0
# 3   4       MM             227        1     1.69     1.69    0.00     0.0
# 4   5       CH             228        7     1.69     1.69    0.00     0.0
#
#    SpecialCH  SpecialMM   LoyalCH  SalePriceMM  SalePriceCH  PriceDiff Store7  \
# 0          0          0  0.500000         1.99         1.75       0.24     No
# 1          0          1  0.600000         1.69         1.75      -0.06     No
# 2          0          0  0.680000         2.09         1.69       0.40     No
# 3          0          0  0.400000         1.69         1.69       0.00     No
# 4          0          0  0.956535         1.69         1.69       0.00    Yes
#
#    PctDiscMM  PctDiscCH  ListPriceDiff  STORE
# ...

# %%
from pycaret.classification import *
clf1 = setup(data, target = 'Purchase', session_id=123)
# Out:
# <style type="text/css">
# #T_86ab1_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_86ab1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_86ab1_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_86ab1_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86ab1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_86ab1_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_86ab1_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_86ab1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_86ab1_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_86ab1_row1_col1" class="data row1 col1" >Purchase</td>
#     </tr>
#     <tr>
#       <th id="T_86ab1_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()

# you can save top models, or manually, like
top3_models = compare_models( n_select=3 )
lda = create_model('lda')
dt = create_model('dt')
# Out:
# <style type="text/css">
# #T_efb58 th {
#   text-align: left;
# }
# ...

# %%
tuned_model = tune_model(best_model)
# Out:
# <style type="text/css">
# #T_528a2_row10_col0, #T_528a2_row10_col1, #T_528a2_row10_col2, #T_528a2_row10_col3, #T_528a2_row10_col4, #T_528a2_row10_col5, #T_528a2_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_528a2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_528a2_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_528a2_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_528a2_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_528a2_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_528a2_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_528a2_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_528a2_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
evaluate_model(tuned_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
