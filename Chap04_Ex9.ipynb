# %% [markdown]
# <a href="https://colab.research.google.com/github/harada26009/TU_M_Math/blob/main/Chap04_Ex9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 練習問題4-1

# %%
from ast import increment_lineno
import numpy as np
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame

#可視化ライブラリ
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline

#小数第３位まで表示
# %precision 3

#ランダムシードの固定
np.random.seed(0)

# %%
coin_data = np.array([0,1])
coin_steps = 1000


coin_rolls = np.random.choice(coin_data,coin_steps)

for i in [0,1]:
  print(i,'が出る確率',len(coin_rolls[coin_rolls==i])/coin_steps)
# Out:
# 0 が出る確率 0.496
# 1 が出る確率 0.504

# %% [markdown]
# 練習問題4-2
# (100/1000)*(99/999)=11/1110

# %% [markdown]
# 練習問題4-3
# 0.99*0,001/(0.99*0,001+0.03*0.999)

# %% [markdown]
# 練習問題4-4

# %%
N=10000
normal_sample_data = [np.random.normal(0,1,100).mean() for _ in range(N)]

plt.hist(normal_sample_data)
plt.grid(True)

# %% [markdown]
# 練習問題4-5

# %%
N=10000
normal_sample_data = [np.random.lognormal(0,1,100).mean() for _ in range(N)]

plt.hist(normal_sample_data)
plt.grid(True)

# %% [markdown]
# 練習問題4-6

# %% [markdown]
# 練習問題4-7

# %%
for df, c in zip([5,25,50],'bgr'):
  x = np.random.chisquare(df,1000)
  plt.hist(x, 20, color=c)

# %% [markdown]
# 練習問題4-8

# %%
x = np.random.standard_t(100,1000)
plt.hist(x)
plt.grid(True)

# %% [markdown]
# 練習問題4-9

# %%
for df, c in zip([(10,30),(20,25)],'bgr'):
  x = np.random.f(df[0],df[1],1000)
  plt.hist(x,100,color=c)
